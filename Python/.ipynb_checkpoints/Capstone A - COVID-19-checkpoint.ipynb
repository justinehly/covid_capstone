# %% [markdown]
# # <font color='blue'>Capstone A</font>
# ## <font color='blue'>Using Hospital Bed Capacity Prediction During COVID-19 to Determine Feature Importance</font>
#
# <b>Abstract.</b>  The Covid-19 pandemic has led to the generation of multiple types of models and feature selection methods in the field of Machine Learning. Since there has been rapid change and new regulations being introduced during the pandemic, modeling and feature selection methods have become increasingly complicated. The purpose of this study is to investigate and dive into key features to help create an understanding for the public and help show preventive measures. This study focuses on the exploration of feature selection though building multiple models, one simple linear model, one more complex model and an average of the two for prediction on impatient hospitalization rates.<br><br>
#
# <b>Authors:</b>
# * Helen Barrera, SMU MSDS Student
# * Justin Ehly, SMU MSDS Student
# * Blake Freeman, SMU MSDS Student
# * Brad Blanchard, SMU Faculty
# * Chris Papesh, UNLV Faculty

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sbs
import copy

# change OS Justin
os.chdir(r'C:\Users\justi\OneDrive - Southern Methodist University\Capstone\data')

# %%
df = pd.read_csv('OxCGRT_latest.csv', low_memory=False)

# create dataframe of only USA State level data
covid = copy.deepcopy(df.loc[(df.RegionName.notna()) & (df.CountryCode == 'USA')]) 
covid.reset_index(drop=True, inplace=True)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33405 entries, 0 to 33404
# Data columns (total 51 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   CountryName                            33405 non-null  object
#  1   CountryCode                            33405 non-null  object
#  2   RegionName                             33405 non-null  object
#  3   RegionCode                             33405 non-null  object
#  4   Jurisdiction                           33405 non-null  object
#  5   Date                                   33405 non-null  int64
#  6   C1_School closing                      32645 non-null  float64
#  7   C1_Flag                                27360 non-null  float64
#  8   C2_Workplace closing                   32582 non-null  float64
#  9   C2_Flag                                24546 non-null  float64
#  10  C3_Cancel public events                32603 non-null  float64
#  11  C3_Flag                                27256 non-null  float64
#  12  C4_Restrictions on gatherings          32646 non-null  float64
#  13  C4_Flag                                20462 non-null  float64
#  14  C5_Close public transport              32650 non-null  float64
#  15  C5_Flag                                11155 non-null  float64
#  16  C6_Stay at home requirements           32632 non-null  float64
#  17  C6_Flag                                21627 non-null  float64
#  18  C7_Restrictions on internal movement   32587 non-null  float64
#  19  C7_Flag                                28802 non-null  float64
#  20  C8_International travel controls       32610 non-null  float64
#  21  E1_Income support                      32480 non-null  float64
#  22  E1_Flag                                25598 non-null  float64
#  23  E2_Debt/contract relief                32555 non-null  float64
#  24  E3_Fiscal measures                     12047 non-null  float64
#  25  E4_International support               11919 non-null  float64
#  26  H1_Public information campaigns        32629 non-null  float64
#  27  H1_Flag                                30369 non-null  float64
#  28  H2_Testing policy                      32634 non-null  float64
#  29  H3_Contact tracing                     32520 non-null  float64
#  30  H4_Emergency investment in healthcare  11851 non-null  float64
#  31  H5_Investment in vaccines              12742 non-null  float64
#  32  H6_Facial Coverings                    32118 non-null  float64
#  33  H6_Flag                                27387 non-null  float64
#  34  H7_Vaccination policy                  15540 non-null  float64
#  35  H7_Flag                                14807 non-null  float64
#  36  H8_Protection of elderly people        32421 non-null  float64
#  37  H8_Flag                                28844 non-null  float64
#  38  M1_Wildcard                            0 non-null      float64
#  39  ConfirmedCases                         32232 non-null  float64
#  40  ConfirmedDeaths                        32232 non-null  float64
#  41  StringencyIndex                        32563 non-null  float64
#  42  StringencyIndexForDisplay              32563 non-null  float64
#  43  StringencyLegacyIndex                  32617 non-null  float64
#  44  StringencyLegacyIndexForDisplay        32617 non-null  float64
#  45  GovernmentResponseIndex                32563 non-null  float64
#  46  GovernmentResponseIndexForDisplay      32563 non-null  float64
#  47  ContainmentHealthIndex                 32575 non-null  float64
#  48  ContainmentHealthIndexForDisplay       32575 non-null  float64
#  49  EconomicSupportIndex                   32358 non-null  float64
#  50  EconomicSupportIndexForDisplay         32358 non-null  float64
# dtypes: float64(45), int64(1), object(5)
# memory usage: 13.0+ MB

# %%
# fix date column
from datetime import datetime
covid.Date = pd.to_datetime(covid.Date, format='%Y%m%d')


# drop the wildcard since it is blank
covid = covid.drop(columns =['M1_Wildcard'])

# %%
# get date range
print(covid.Date.min(), covid.Date.max())
# Out:
# 2020-01-01 00:00:00 2021-10-16 00:00:00

# %%
# This is a backtrack piece of code to truncate the data set since it appers the last dates have NaNs for Cases/Deaths

def non_zero_cases(covid):
    true_end = covid.groupby(by='Date').sum()[['ConfirmedCases']]
    true_end.reset_index(inplace=True)
    non_zero = np.where(true_end.ConfirmedCases !=0)[0]
    return non_zero, true_end

def start_date():
    non_zero, true_end = non_zero_cases(covid)
    start = np.argmin(non_zero)
    start_date = covid.Date >= true_end.Date[non_zero[start]]
    return start_date
    
def stop_date():
    non_zero, true_end = non_zero_cases(covid)
    stop = np.argmax(non_zero)
    stop_date = covid.Date <= true_end.Date[non_zero[stop]]
    return stop_date

# %%
# set date range to remove missing values
start = start_date()
end = stop_date()
covid = covid.loc[start & end]

# confirm new date range
print(min(covid.Date), max(covid.Date))
# Out:
# 2020-01-22 00:00:00 2021-10-14 00:00:00

# %%
df.shape
# Out:
# (204360, 51)

# %%
covid.shape
# Out:
# (32232, 50)

# %%
desc = pd.DataFrame(covid.describe())
desc.T
# Out:
#                                          count          mean           std  \
# C1_School closing                      31574.0  1.758852e+00  9.875849e-01
# C1_Flag                                27360.0  4.472953e-01  4.972235e-01
# C2_Workplace closing                   31511.0  1.194091e+00  8.434590e-01
# C2_Flag                                24546.0  7.684755e-01  4.218153e-01
# C3_Cancel public events                31532.0  1.184828e+00  6.495357e-01
# C3_Flag                                27256.0  7.943572e-01  4.041780e-01
# C4_Restrictions on gatherings          31575.0  2.160728e+00  1.718146e+00
# C4_Flag                                20462.0  7.124426e-01  4.526347e-01
# C5_Close public transport              31579.0  4.084360e-01  5.933102e-01
# C5_Flag                                11155.0  3.050650e-01  4.604556e-01
# C6_Stay at home requirements           31561.0  8.207598e-01  6.466507e-01
# C6_Flag                                21627.0  7.743561e-01  4.180153e-01
# C7_Restrictions on internal movement   31516.0  1.094872e+00  5.080451e-01
# C7_Flag                                28802.0  9.044511e-01  2.939767e-01
# C8_International travel controls       31539.0  2.812454e+00  7.172726e-01
# E1_Income support                      31409.0  1.086950e+00  6.703917e-01
# E1_Flag                                25598.0  2.440816e-01  4.295497e-01
# E2_Debt/contract relief                31484.0  1.190255e+00  6.329869e-01
# E3_Fiscal measures                     11501.0  2.030496e+06  8.434722e+07
# E4_International support               11373.0  0.000000e+00  0.000000e+00
# H1_Public information campaigns        31558.0  1.887540e+00  4.209506e-01
# H1_Flag                                30337.0  9.826285e-01  1.306534e-01
# H2_Testing policy                      31563.0  2.380667e+00  7.887846e-01
# H3_Contact tracing                     31449.0  1.438774e+00  4.962451e-01
# H4_Emergency investment in healthcare  11305.0  5.409452e+05  2.112974e+07
# H5_Investment in vaccines              12173.0  1.076152e+04  1.005227e+06
# H6_Facial Coverings                    31047.0  2.153928e+00  1.041888e+00
# H6_Flag                                27387.0  6.895242e-01  4.626969e-01
# H7_Vaccination policy                  15540.0  3.820721e+00  1.552118e+00
# H7_Flag                                14807.0  1.000000e+00  0.000000e+00
# H8_Protection of elderly people        31350.0  1.865423e+00  8.385056e-01
# H8_Flag                                28844.0  8.947441e-01  3.068881e-01
# ConfirmedCases                         32232.0  3.461704e+05  5.959413e+05
# ConfirmedDeaths                        32232.0  6.518810e+03  1.068902e+04
# StringencyIndex                        31492.0  4.999142e+01  1.958015e+01
# StringencyIndexForDisplay              31492.0  4.999142e+01  1.958015e+01
# StringencyLegacyIndex                  31546.0  5.926684e+01  1.927058e+01
# StringencyLegacyIndexForDisplay        31546.0  5.926684e+01  1.927058e+01
# GovernmentResponseIndex                31492.0  5.290297e+01  1.598573e+01
# GovernmentResponseIndexForDisplay      31492.0  5.290297e+01  1.598573e+01
# ContainmentHealthIndex                 31504.0  5.344772e+01  1.556078e+01
# ContainmentHealthIndexForDisplay       31504.0  5.344772e+01  1.556078e+01
# EconomicSupportIndex                   31287.0  4.921573e+01  2.528799e+01
# EconomicSupportIndexForDisplay         31287.0  4.921573e+01  2.528799e+01
#
#                                         min       25%        50%        75%  \
# C1_School closing                      0.00      1.00       2.00       3.00
# C1_Flag                                0.00      0.00       0.00       1.00
# C2_Workplace closing                   0.00      1.00       1.00       2.00
# C2_Flag                                0.00      1.00       1.00       1.00
# C3_Cancel public events                0.00      1.00       1.00       2.00
# C3_Flag                                0.00      1.00       1.00       1.00
# C4_Restrictions on gatherings          0.00      0.00       3.00       4.00
# C4_Flag                                0.00      0.00       1.00       1.00
# C5_Close public transport              0.00      0.00       0.00       1.00
# C5_Flag                                0.00      0.00       0.00       1.00
# C6_Stay at home requirements           0.00      0.00       1.00       1.00
# C6_Flag                                0.00      1.00       1.00       1.00
# C7_Restrictions on internal movement   0.00      1.00       1.00       1.00
# C7_Flag                                0.00      1.00       1.00       1.00
# C8_International travel controls       0.00      3.00       3.00       3.00
# E1_Income support                      0.00      1.00       1.00       2.00
# E1_Flag                                0.00      0.00       0.00       0.00
# E2_Debt/contract relief                0.00      1.00       1.00       2.00
# E3_Fiscal measures                     0.00      0.00       0.00       0.00
# E4_International support               0.00      0.00       0.00       0.00
# H1_Public information campaigns        0.00      2.00       2.00       2.00
# H1_Flag                                0.00      1.00       1.00       1.00
# H2_Testing policy                      0.00      2.00       3.00       3.00
# H3_Contact tracing                     1.00      1.00       1.00       2.00
# H4_Emergency investment in healthcare  0.00      0.00       0.00       0.00
# H5_Investment in vaccines              0.00      0.00       0.00       0.00
# H6_Facial Coverings                    0.00      2.00       2.00       3.00
# H6_Flag                                0.00      0.00       1.00       1.00
# H7_Vaccination policy                  0.00      2.00       5.00       5.00
# H7_Flag                                1.00      1.00       1.00       1.00
# H8_Protection of elderly people        0.00      1.00       2.00       2.00
# H8_Flag                                0.00      1.00       1.00       1.00
# ConfirmedCases                         0.00  16989.75  115666.50  442360.50
# ConfirmedDeaths                        0.00    377.00    2166.50    7742.00
# StringencyIndex                        0.00     37.96      53.24      62.96
# StringencyIndexForDisplay              0.00     37.96      53.24      62.96
# StringencyLegacyIndex                  0.00     51.90      63.10      71.43
# StringencyLegacyIndexForDisplay        0.00     51.90      63.10      71.43
# GovernmentResponseIndex                5.21     47.66      55.73      62.66
# GovernmentResponseIndexForDisplay      5.21     47.66      55.73      62.66
# ContainmentHealthIndex                 5.95     48.51      56.25      62.80
# ContainmentHealthIndexForDisplay       5.95     48.51      56.25      62.80
# EconomicSupportIndex                   0.00     37.50      50.00      62.50
# EconomicSupportIndexForDisplay         0.00     37.50      50.00      62.50
#
#                                                 max
# C1_School closing                      3.000000e+00
# C1_Flag                                1.000000e+00
# C2_Workplace closing                   3.000000e+00
# C2_Flag                                1.000000e+00
# C3_Cancel public events                2.000000e+00
# C3_Flag                                1.000000e+00
# C4_Restrictions on gatherings          4.000000e+00
# C4_Flag                                1.000000e+00
# C5_Close public transport              2.000000e+00
# C5_Flag                                1.000000e+00
# C6_Stay at home requirements           2.000000e+00
# C6_Flag                                1.000000e+00
# C7_Restrictions on internal movement   2.000000e+00
# C7_Flag                                1.000000e+00
# C8_International travel controls       3.000000e+00
# E1_Income support                      2.000000e+00
# E1_Flag                                1.000000e+00
# E2_Debt/contract relief                2.000000e+00
# E3_Fiscal measures                     6.600000e+09
# E4_International support               0.000000e+00
# H1_Public information campaigns        2.000000e+00
# H1_Flag                                1.000000e+00
# H2_Testing policy                      3.000000e+00
# H3_Contact tracing                     2.000000e+00
# H4_Emergency investment in healthcare  1.600000e+09
# H5_Investment in vaccines              1.100000e+08
# H6_Facial Coverings                    4.000000e+00
# H6_Flag                                1.000000e+00
# H7_Vaccination policy                  5.000000e+00
# H7_Flag                                1.000000e+00
# H8_Protection of elderly people        3.000000e+00
# H8_Flag                                1.000000e+00
# ConfirmedCases                         4.802761e+06
# ConfirmedDeaths                        7.045600e+04
# StringencyIndex                        9.352000e+01
# StringencyIndexForDisplay              9.352000e+01
# StringencyLegacyIndex                  9.643000e+01
# StringencyLegacyIndexForDisplay        9.643000e+01
# GovernmentResponseIndex                8.047000e+01
# GovernmentResponseIndexForDisplay      8.047000e+01
# ContainmentHealthIndex                 8.048000e+01
# ContainmentHealthIndexForDisplay       8.048000e+01
# EconomicSupportIndex                   1.000000e+02
# EconomicSupportIndexForDisplay         1.000000e+02

# %%
idx_na = copy.deepcopy(covid[(covid.StringencyIndex.isna() | covid.StringencyLegacyIndex.isna())])
idx_na.iloc[:,2:38]
# Out:
#       RegionName RegionCode Jurisdiction       Date  C1_School closing  \
# 643       Alaska      US_AK  STATE_TOTAL 2021-10-05                NaN
# 644       Alaska      US_AK  STATE_TOTAL 2021-10-06                NaN
# 645       Alaska      US_AK  STATE_TOTAL 2021-10-07                NaN
# 646       Alaska      US_AK  STATE_TOTAL 2021-10-08                NaN
# 647       Alaska      US_AK  STATE_TOTAL 2021-10-09                NaN
# ...          ...        ...          ...        ...                ...
# 33398    Wyoming      US_WY  STATE_TOTAL 2021-10-10                NaN
# 33399    Wyoming      US_WY  STATE_TOTAL 2021-10-11                NaN
# 33400    Wyoming      US_WY  STATE_TOTAL 2021-10-12                NaN
# 33401    Wyoming      US_WY  STATE_TOTAL 2021-10-13                NaN
# 33402    Wyoming      US_WY  STATE_TOTAL 2021-10-14                NaN
#
#        C1_Flag  C2_Workplace closing  C2_Flag  C3_Cancel public events  \
# 643        NaN                   NaN      NaN                      NaN
# 644        NaN                   NaN      NaN                      NaN
# 645        NaN                   NaN      NaN                      NaN
# 646        NaN                   NaN      NaN                      NaN
# 647        NaN                   NaN      NaN                      NaN
# ...        ...                   ...      ...                      ...
# 33398      NaN                   NaN      NaN                      NaN
# 33399      NaN                   NaN      NaN                      NaN
# 33400      NaN                   NaN      NaN                      NaN
# 33401      NaN                   NaN      NaN                      NaN
# 33402      NaN                   NaN      NaN                      NaN
#
#        C3_Flag  ...  H2_Testing policy  H3_Contact tracing  \
# 643        NaN  ...                NaN                 NaN
# 644        NaN  ...                NaN                 NaN
# 645        NaN  ...                NaN                 NaN
# 646        NaN  ...                NaN                 NaN
# 647        NaN  ...                NaN                 NaN
# ...        ...  ...                ...                 ...
# 33398      NaN  ...                NaN                 NaN
# 33399      NaN  ...                NaN                 NaN
# 33400      NaN  ...                NaN                 NaN
# 33401      NaN  ...                NaN                 NaN
# 33402      NaN  ...                NaN                 NaN
#
#        H4_Emergency investment in healthcare  H5_Investment in vaccines  \
# 643                                      NaN                        NaN
# 644                                      NaN                        NaN
# 645                                      NaN                        NaN
# 646                                      NaN                        NaN
# 647                                      NaN                        NaN
# ...                                      ...                        ...
# 33398                                    NaN                        NaN
# 33399                                    NaN                        NaN
# 33400                                    NaN                        NaN
# 33401                                    NaN                        NaN
# 33402                                    NaN                        NaN
#
#        H6_Facial Coverings  H6_Flag  H7_Vaccination policy  H7_Flag  \
# 643                    NaN      NaN                    NaN      NaN
# 644                    NaN      NaN                    NaN      NaN
# 645                    NaN      NaN                    NaN      NaN
# 646                    NaN      NaN                    NaN      NaN
# 647                    NaN      NaN                    NaN      NaN
# ...                    ...      ...                    ...      ...
# 33398                  NaN      NaN                    NaN      NaN
# 33399                  NaN      NaN                    NaN      NaN
# 33400                  NaN      NaN                    NaN      NaN
# 33401                  NaN      NaN                    NaN      NaN
# 33402                  NaN      NaN                    NaN      NaN
#
#        H8_Protection of elderly people  H8_Flag
# 643                                NaN      NaN
# 644                                NaN      NaN
# 645                                NaN      NaN
# 646                                NaN      NaN
# 647                                NaN      NaN
# ...                                ...      ...
# 33398                              NaN      NaN
# 33399                              NaN      NaN
# 33400                              NaN      NaN
# 33401                              NaN      NaN
# 33402                              NaN      NaN
#
# [740 rows x 36 columns]

# %% [markdown]
# ---
# ### Missing Values
# ---
# codebook https://github.com/OxCGRT/covid-policy-tracker/blob/master/documentation/codebook.md
#
# - <b>All C1 - H8</b>
#     - features should be changed to categorical
#     - NaN means there was no data available, s/b set to 99 and then 'no_data' because it may be useful
#     <br><br>
# - <b>Changes to be aware of:</b>
#     - 27 September 2021: v3.4 note about removal of E3, E4 and H4
#     - 28 June 2021: v3.3 presenting the imputed vaccine indicators (V2 summary and V3 summary) into a separate table
#     - 21 June 2021: v3.02 edits to vaccine policy indicators table, fixing age ranges12 June 2021: v3.01 added section for vaccine policies
#     - 5 May 2021: v2.10 added 'or all businesses open with alterations resulting in significant differences compared to non-Covid-19 operations' to C2 level 1
#     - 18 March 2021: v2.9 added H8 'Protection of elderly people' indicator
#     - 05 March 2021: v2.8 added 'non elderly' to definition of Clinically vulnerable groups' for H7
#     - 14 January 2021: v2.7 changed 'country' to 'country/territory' and removed 'private' from C4 definition, replaced E1 flag 'formal sector workers only' to 'formal sector workers only or informal sector workers only', and 'informal workers too' to 'all workers'

# %%
# replace NaN with 99
covid.iloc[:,6:38] = covid.iloc[:,6:38].fillna(99)

# %%
# All C1 - H8 features should be changed to categorical
# first convert to int to remove dot.zero

covid.iloc[:,6:38] = covid.iloc[:,6:38].astype('int')
covid.iloc[:,6:38] = covid.iloc[:,6:38].astype('category')

# %%
covid.iloc[:,6:38].replace(to_replace = 99, value = 'no_data', inplace=True)

# %% [markdown]
# ---
# ### Missing Values p2
# ---
# - codebook https://github.com/OxCGRT/covid-policy-tracker/blob/master/documentation/codebook.md
# - Indices methodology: https://github.com/OxCGRT/covid-policy-tracker/blob/master/documentation/index_methodology.md
# <br>
# - Oxford researchers were very conservative in the computation of indicies (more can be read at [indices methology link](https://github.com/OxCGRT/covid-policy-tracker/blob/master/documentation/index_methodology.md)  above)
# - We can be more liberal for our research and will assume there was no change in policies where data is unreported for certain dates but does exist prior

# %%
from sklearn.impute import SimpleImputer
# replace NaN previous index
covid.iloc[:,40:50] = covid.iloc[:,40:50].fillna(method = 'ffill', axis=0)

# %%
covid.isna().sum()
# Out:
# CountryName                              0
# CountryCode                              0
# RegionName                               0
# RegionCode                               0
# Jurisdiction                             0
# Date                                     0
# C1_School closing                        0
# C1_Flag                                  0
# C2_Workplace closing                     0
# C2_Flag                                  0
# C3_Cancel public events                  0
# C3_Flag                                  0
# C4_Restrictions on gatherings            0
# C4_Flag                                  0
# C5_Close public transport                0
# C5_Flag                                  0
# C6_Stay at home requirements             0
# C6_Flag                                  0
# C7_Restrictions on internal movement     0
# C7_Flag                                  0
# C8_International travel controls         0
# E1_Income support                        0
# E1_Flag                                  0
# E2_Debt/contract relief                  0
# E3_Fiscal measures                       0
# E4_International support                 0
# H1_Public information campaigns          0
# H1_Flag                                  0
# H2_Testing policy                        0
# H3_Contact tracing                       0
# H4_Emergency investment in healthcare    0
# H5_Investment in vaccines                0
# H6_Facial Coverings                      0
# H6_Flag                                  0
# H7_Vaccination policy                    0
# H7_Flag                                  0
# H8_Protection of elderly people          0
# H8_Flag                                  0
# ConfirmedCases                           0
# ConfirmedDeaths                          0
# StringencyIndex                          0
# StringencyIndexForDisplay                0
# StringencyLegacyIndex                    0
# StringencyLegacyIndexForDisplay          0
# GovernmentResponseIndex                  0
# GovernmentResponseIndexForDisplay        0
# ContainmentHealthIndex                   0
# ContainmentHealthIndexForDisplay         0
# EconomicSupportIndex                     0
# EconomicSupportIndexForDisplay           0
# dtype: int64

# %%
covid.iloc[:,0:5] = covid.iloc[:,0:5].astype('category') # make sure the first 4 features are categorical
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32232 entries, 0 to 32231
# Data columns (total 50 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   CountryName                            32232 non-null  category
#  1   CountryCode                            32232 non-null  category
#  2   RegionName                             32232 non-null  category
#  3   RegionCode                             32232 non-null  category
#  4   Jurisdiction                           32232 non-null  category
#  5   Date                                   32232 non-null  datetime64[ns]
#  6   C1_School closing                      32232 non-null  category
#  7   C1_Flag                                32232 non-null  category
#  8   C2_Workplace closing                   32232 non-null  category
#  9   C2_Flag                                32232 non-null  category
#  10  C3_Cancel public events                32232 non-null  category
#  11  C3_Flag                                32232 non-null  category
#  12  C4_Restrictions on gatherings          32232 non-null  category
#  13  C4_Flag                                32232 non-null  category
#  14  C5_Close public transport              32232 non-null  category
#  15  C5_Flag                                32232 non-null  category
#  16  C6_Stay at home requirements           32232 non-null  category
#  17  C6_Flag                                32232 non-null  category
#  18  C7_Restrictions on internal movement   32232 non-null  category
#  19  C7_Flag                                32232 non-null  category
#  20  C8_International travel controls       32232 non-null  category
#  21  E1_Income support                      32232 non-null  category
#  22  E1_Flag                                32232 non-null  category
#  23  E2_Debt/contract relief                32232 non-null  category
#  24  E3_Fiscal measures                     32232 non-null  category
#  25  E4_International support               32232 non-null  category
#  26  H1_Public information campaigns        32232 non-null  category
#  27  H1_Flag                                32232 non-null  category
#  28  H2_Testing policy                      32232 non-null  category
#  29  H3_Contact tracing                     32232 non-null  category
#  30  H4_Emergency investment in healthcare  32232 non-null  category
#  31  H5_Investment in vaccines              32232 non-null  category
#  32  H6_Facial Coverings                    32232 non-null  category
#  33  H6_Flag                                32232 non-null  category
#  34  H7_Vaccination policy                  32232 non-null  category
#  35  H7_Flag                                32232 non-null  category
#  36  H8_Protection of elderly people        32232 non-null  category
#  37  H8_Flag                                32232 non-null  category
#  38  ConfirmedCases                         32232 non-null  float64
#  39  ConfirmedDeaths                        32232 non-null  float64
#  40  StringencyIndex                        32232 non-null  float64
#  41  StringencyIndexForDisplay              32232 non-null  float64
#  42  StringencyLegacyIndex                  32232 non-null  float64
#  43  StringencyLegacyIndexForDisplay        32232 non-null  float64
#  44  GovernmentResponseIndex                32232 non-null  float64
#  45  GovernmentResponseIndexForDisplay      32232 non-null  float64
#  46  ContainmentHealthIndex                 32232 non-null  float64
#  47  ContainmentHealthIndexForDisplay       32232 non-null  float64
#  48  EconomicSupportIndex                   32232 non-null  float64
#  49  EconomicSupportIndexForDisplay         32232 non-null  float64
# dtypes: category(37), datetime64[ns](1), float64(12)
# memory usage: 4.3 MB

# %%
covid.reset_index(inplace = True, drop = True)

# %% [markdown]
# ### Note:
# https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u
# from the healthdata.gov data we will get our matching keys:
# * collection_week: This date indicates the start of the period of reporting (the starting Friday).
# * state: [FAQ - 1. d)] The two digit state/territory code for the hospital.
#
# ToDo:
# * reduce the DF to a date range to Jan 24th (Friday) - May27 2021 (Thursday) this will match the data set weeks we are merging with
# * combine the covid dataframe into weekly numbers with weeks beginning on 1/24/20
# * create a state feature from RegionName

# %%
# reduce covid df to friday 01-24-20 thru thursday 05-27-21
start_date = pd.to_datetime('20200124')
end_date = pd.to_datetime('20210527')

date_reduce_idx = np.where((covid.Date >= start_date) & (covid.Date <= end_date))
covid = covid.loc[date_reduce_idx]
min(covid.Date), max(covid.Date)
# Out:
# (Timestamp('2020-01-24 00:00:00'), Timestamp('2021-05-27 00:00:00'))

# %%
# combine the weeks in the covid df
import datetime
min(covid.Date) + datetime.timedelta(6)
#covid.groupby(by='Date').sum()[['ConfirmedCases']]
# look up pd.Grouper
# https://stackoverflow.com/questions/45281297/group-by-week-in-pandas/45281418
# Out:
# Timestamp('2020-01-30 00:00:00')

# %% [markdown]
# ---
# ## EDA
# ---

# %% [markdown]
# ---
# ### Graph to compare Cases and Deaths over time
# --

# %%
# get an idea of how the cases and deaths align over time when scaled
fig, ax1 = plt.subplots(figsize=(12,5))

# plot conf_cases
color = 'tab:red'
ax1.set_xlabel('Dates')
ax1.set_ylabel('Confirmed Casess')
ax1.plot(covid.groupby(by='Date').sum()['ConfirmedCases'], color=color, label='Conf_Cases')
ax1.tick_params(axis='y', labelcolor=color)

# add additional axes to same plot
ax2 = ax1.twinx()

# plot conf_deaths
color = 'tab:blue'
ax2.set_ylabel('Confirmed Deaths')
ax2.plot(covid.groupby(by='Date').sum()['ConfirmedDeaths'], color=color, label='Conf_Deaths')
ax2.tick_params(axis='y', labelcolor=color)

# prevent any offsets
fig.tight_layout()

# get plotted objects and their labels
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='lower right')
ax2.set_title('Explore the Similarity in Tranjectories of Cases and Deaths')
ax2.legend(lines + lines2, labels + labels2, loc=0)
plt.show()

# %%
covid
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 21     United States         USA     Alaska      US_AK  STATE_TOTAL
# 22     United States         USA     Alaska      US_AK  STATE_TOTAL
# 23     United States         USA     Alaska      US_AK  STATE_TOTAL
# 24     United States         USA     Alaska      US_AK  STATE_TOTAL
# 25     United States         USA     Alaska      US_AK  STATE_TOTAL
# ...              ...         ...        ...        ...          ...
# 33398  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 33399  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 33400  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 33401  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 33402  United States         USA    Wyoming      US_WY  STATE_TOTAL
#
#             Date C1_School closing  C1_Flag C2_Workplace closing  C2_Flag  \
# 21    2020-01-22                 0  no_data                    0  no_data
# 22    2020-01-23                 0  no_data                    0  no_data
# 23    2020-01-24                 0  no_data                    0  no_data
# 24    2020-01-25                 0  no_data                    0  no_data
# 25    2020-01-26                 0  no_data                    0  no_data
# ...          ...               ...      ...                  ...      ...
# 33398 2021-10-10           no_data  no_data              no_data  no_data
# 33399 2021-10-11           no_data  no_data              no_data  no_data
# 33400 2021-10-12           no_data  no_data              no_data  no_data
# 33401 2021-10-13           no_data  no_data              no_data  no_data
# 33402 2021-10-14           no_data  no_data              no_data  no_data
#
#        ... StringencyIndex StringencyIndexForDisplay StringencyLegacyIndex  \
# 21     ...            5.56                      5.56                  9.52
# 22     ...            5.56                      5.56                  9.52
# 23     ...            5.56                      5.56                  9.52
# 24     ...            5.56                      5.56                  9.52
# 25     ...            5.56                      5.56                  9.52
# ...    ...             ...                       ...                   ...
# 33398  ...           33.33                     33.33                 44.05
# 33399  ...           33.33                     33.33                 44.05
# 33400  ...           33.33                     33.33                 44.05
# 33401  ...           33.33                     33.33                 44.05
# 33402  ...           33.33                     33.33                 44.05
#
#       StringencyLegacyIndexForDisplay GovernmentResponseIndex  \
# 21                               9.52                    8.33
# 22                               9.52                    8.33
# 23                               9.52                    8.33
# 24                               9.52                    8.33
# 25                               9.52                    8.33
# ...                               ...                     ...
# 33398                           44.05                   38.54
# 33399                           44.05                   38.54
# 33400                           44.05                   38.54
# 33401                           44.05                   38.54
# 33402                           44.05                   38.54
#
#       GovernmentResponseIndexForDisplay ContainmentHealthIndex  \
# 21                                 8.33                   9.52
# 22                                 8.33                   9.52
# 23                                 8.33                   9.52
# 24                                 8.33                   9.52
# 25                                 8.33                   9.52
# ...                                 ...                    ...
# 33398                             38.54                  44.05
# 33399                             38.54                  44.05
# 33400                             38.54                  44.05
# 33401                             38.54                  44.05
# 33402                             38.54                  44.05
#
#       ContainmentHealthIndexForDisplay EconomicSupportIndex  \
# 21                                9.52                  0.0
# 22                                9.52                  0.0
# 23                                9.52                  0.0
# 24                                9.52                  0.0
# 25                                9.52                  0.0
# ...                                ...                  ...
# 33398                            44.05                  0.0
# 33399                            44.05                  0.0
# 33400                            44.05                  0.0
# 33401                            44.05                  0.0
# 33402                            44.05                  0.0
#
#       EconomicSupportIndexForDisplay
# 21                               0.0
# 22                               0.0
# 23                               0.0
# 24                               0.0
# 25                               0.0
# ...                              ...
# 33398                            0.0
# 33399                            0.0
# 33400                            0.0
# 33401                            0.0
# 33402                            0.0
#
# [32232 rows x 50 columns]
